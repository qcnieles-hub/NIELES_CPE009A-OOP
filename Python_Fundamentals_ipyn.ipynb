# %% [markdown]
# <a href="https://colab.research.google.com/github/qcnieles-hub/NIELES_CPE009A-OOP/blob/main/Python_Fundamentals_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
if 5>2:
 print("five is greater than Two")
# Out:
# five is greater than Two

# %% [markdown]
# Pyhton Comments

# %%
#This is a comments
print("Hello,World")
# Out:
# Hello,World

# %% [markdown]
# Pyhton Variable

# %%
X = 1
a, b=0,-1
a, b, c=0,-1,2

b= "Sally" #This is a type of string
print(b)
# Out:
# Sally

# %% [markdown]
# Casting

# %%
b="sally" #This is a type of string
b=int(4)
print(b)

b=float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# Type() Function

# %%
x = 5
y="John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# "Double quotes" or 'Single' qoutes

# %%
y= "JOhn"
y= 'John'
print(y)
# Out:
# John

# %% [markdown]
# Case sensitive

# %%
a = 4
A = "Sally"
#A will not overwrite a

# %% [markdown]
# Multiple Variables

# %%
x, y, z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# One Value to Multiple Variables

# %%
x = y = z = "four"
print(x, y, z)
# Out:
# four four four

# %% [markdown]
# Output Variable

# %%
x ="enjoying"
print("Pythhon programming is " + x)
# Out:
# Pythhon programming is enjoying

# %% [markdown]
# Other way:

# %%
x = "Python is"
y ="enjoying"
z = x + y
print(z)
# Out:
# Python isenjoying

# %% [markdown]
# Arithmetic Operation

# %%
from ast import Yield
x = 5
y = 3
print(x + y)

x=5
y=3
sum=x+y
sum

x = 15
y = 5
print(x*y)

#Addition  " x + y"
#Subtraction " x - y"
#Multiplication " x *y"
#Division " x / y"
#Modulos " x % y"
# Out:
# 8
# 8

# %% [markdown]
# Assigment Operator

# %%
s = 1
s += 3
print(s)

s = 1
s = s + 3
print(s)





#" = "
x = 5
print(s)


#" += "
s = 3
print(s)


#" -= "
s = 3
print(s)


#" *= "
s = 3
print(s)


#" /= "
s = 3
print(s)


#" %= "
s = 3
print(s)
# Out:
# 4
# 4
# 4
# 3
# 3
# 3
# 3

# %% [markdown]
#  Comparison Operators

# %%
#Equal "x == y"
#Not equal " x !="
#Greater than  "x >= y"
#Less than " x > y"
#Greater than or Equal to "x >= y"
#Less than or Equa to "x  <= y"

t = 1
u = 2
t>u
t<u
t>=u
t<=u
t==u
t!=u
# Out:
# True

# %% [markdown]
# Logical Operators

# %%
#And  *x < 5 and  x < 10"
print(t < 5 and u < 10)


#0r  *x < 5 or  x < 10"
print( t < 5 or u <  10)


#Not "not(x < 5 and x < 10)"
print(not(t < 5 and u < 10))
# Out:
# True
# True
# False

# %% [markdown]
# Identity Operators

# %%
#Is

#Is not "x is not y"

# %% [markdown]
# Bitwise Operator

# %%
#Given
v = 2

#ADD(&)
V = 1
print(v & 1)

#OR(!)
V = 1
print(v |1)


#XOR(^)
V = 1
print(v ^ 1 )

#NOT(~)
V = 2
print(~v)

#Zero fill left shift (<<)
v = 2
print(v << 1)

#Signed right shift (>>)
v = 2
print(v >> 1 )
# Out:
# 0
# 3
# 3
# -3
# 4
# 1
