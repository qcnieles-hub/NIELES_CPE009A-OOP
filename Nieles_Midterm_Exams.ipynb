# %% [markdown]
# <a href="https://colab.research.google.com/github/qcnieles-hub/NIELES_CPE009A-OOP/blob/main/Nieles_Midterm_Exams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instruction: Insert the link of your program(Colab/Github) here.
#
# Write a program that uses nested loops to print this pattern:
#
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
for i in range(1, 6):
  print('*' * i)
  if i == 5:
    for j in range(4, 0, -1):
      print('*' * j)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# nstruction: Insert the link of your program(Colab/Github) here.
#
# Write a function that checks if a string of parentheses (), brackets [], and braces {} is balanced.
#
# Examples:
#
# "({[]})" → True
#
# "([)]" → False
#
# "((()))" → True
#
# "({)}" → False

# %%
def is balanced (string):
stack[]
pairs = {')': '(', ']': '[', '}': '{'}

for char in string:
  if char in pairs.values():
    stack.append(char)
