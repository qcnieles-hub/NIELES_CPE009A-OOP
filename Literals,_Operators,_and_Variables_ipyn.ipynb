# %% [markdown]
# <a href="https://colab.research.google.com/github/qcnieles-hub/NIELES_CPE009A-OOP/blob/main/Literals%2C_Operators%2C_and_Variables_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Laboratory Activity No.1** (Literals, Operators, and Variables)

# %% [markdown]
# **Name:** Cenndy M. Nieles
#
# **Section:** CPE12S2
#
# **Date Performed:** January 08, 2026

# %% [markdown]
# Assigning variables of different data types of Phython

# %% [markdown]
# 1.) In an empty cell, declare a variable value and assigned it  and assign it the value of 5 then display its value using print().

# %%
value = 5
print(value)
# Out:
# 5

# %% [markdown]
# 2.) Create a new cell and type the command: type(value) then run the cell. The output should be like the image  below.

# %%
type(value)
# Out:
# int

# %% [markdown]
# 3.) In a new cell, use the same variable value and assign it the value of 5.0 then print the value.

# %%
type(0.5)
# Out:
# float

# %% [markdown]
# 4.) Repeat step 2.
# Note: You may choose to decide how you execute the code in the cells for the next tasks in the procedure.

# %% [markdown]
# 5.) Repeat these steps for the following values:
#
# a. 2+3j
#
# b. ‘Hello World’
#
# c. “Hello World”
#
# d. True
#
# e. False
#
# f. [1,2,3,4,5]
#
# g. (1,2,3,4,5)
#
# h. { ‘name’: ‘Your_name’ }
#
# i. None

# %% [markdown]
# a. 2+3j

# %%
value = 2
value2 =3j
(value + value2)
# Out:
# (2+3j)

# %% [markdown]
# b. 'Hello World'

# %%
value = ("Hello")
value2 = ("World")
(value + " " + value2)
# Out:
# 'Hello World'

# %% [markdown]
# c. "Hello World"

# %%
value = "Hello"
value2 = "World"
(value + " " + value2)
# Out:
# 'Hello World'

# %% [markdown]
# d. True

# %%
value = True
print(value)
type(value)
# Out:
# True
# bool

# %% [markdown]
# e. False

# %%
value = False
print(value)
type(value)
# Out:
# False
# bool

# %% [markdown]
# f. [1,2,3,4,5]

# %%
value = [1, 2, 3, 4, 5]
print(value)
type(value)
# Out:
# [1, 2, 3, 4, 5]
# list

# %% [markdown]
# g. (1,2,3,4,5)

# %%
value = (1, 2, 3, 4, 5)
print(value)
type(value)
# Out:
# (1, 2, 3, 4, 5)
# tuple

# %% [markdown]
# h. { ‘name’: ‘Your_name’ }

# %%
value = {'name': 'Cenndy M. Nieles'}
print(name)
# Out:
# Cenndy M. Nieles

# %% [markdown]
# 6.) Re-assign the value variable to be equal to 5.

# %%
value = 5
print(value)
# Out:
# 5

# %% [markdown]
# 7. Declare a new variable named value2 to be equal to -6.

# %%
value = 5
value2= -6
print(value + value2)
# Out:
# -1

# %% [markdown]
# Performing Operations with Python

# %%
value, value2 = -5.0, 6
print(value + value2)
# Out:
# 1.0

# %% [markdown]
# 1. Using value and value2. Type the command: print(value+value2)

# %% [markdown]
#  a. value, value2 = 5.0, 6

# %%
value, value2 = 5.0, 6
print(value + value2)
# Out:
# 11.0

# %% [markdown]
# b. value, value2 = -5, 6.1

# %%
value, value2 = -5, 6.1
print(value + value2)
# Out:
# 1.0999999999999996

# %% [markdown]
# c. value, value2 = “Hello”, ‘world’

# %%
value, value2 = "Hello", "world"
print(value + " " + value2)
# Out:
# Hello world

# %% [markdown]
# d. value, value2 = [1,2,3], [4,5,6]

# %%
value, value2 = [1, 2, 3], [4, 5, 6]
print(value + value2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# e. value, value2 = (1,2,3), (4,5,6)

# %%
value, value2 = (1, 2, 3), (4, 5, 6)
print(value + value2)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# f. value, value2 = {"name":"Royce"}, {"age":2}

# %%
value, value2 = {"name": "Royce"}, {"age": 2}

print(value)   # {'name': 'Royce'}
print(value2)  # {'age': 2}
# Out:
# {'name': 'Royce'}
# {'age': 2}

# %% [markdown]
# 3. Using value, value2 = 30, 4. Type the commands:

# %% [markdown]
# a. print(value*value2)

# %%
value = 30
value2 = 4

print(value * value2)
# Out:
# 120

# %% [markdown]
#  b. print(value2**2)

# %%
value2 = 4
print(value2 ** 2)
# Out:
# 16

# %% [markdown]
#  c. print(value2**3

# %%
value2 = 4
print(value2 ** 3)
# Out:
# 64

# %% [markdown]
# d. print(value*value2+value2**2+1)

# %%
value2 = 4
print(value2 ** 2+1)
# Out:
# 17

# %% [markdown]
# e. print(value/value2)

# %%
value = 30
value2 = 4

print(value / value2)
# Out:
# 7.5

# %% [markdown]
# f. print(value%value2)

# %%
value = 30
value2 = 4
print(value % value2)
# Out:
# 2

# %% [markdown]
# Assigning Input Data to a Variable

# %% [markdown]
# Finding a person’s BMI (metric)

# %% [markdown]
# 1. Declare a new variable named name and assign it the value input(“Enter your name”)
