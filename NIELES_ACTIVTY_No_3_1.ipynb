# %% [markdown]
# <a href="https://colab.research.google.com/github/qcnieles-hub/NIELES_CPE009A-OOP/blob/main/NIELES_ACTIVTY_No_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# HOA_3.1

# %% [markdown]
# Step. 1 Create a variable numberlist and assign it the value of [5,4,2,1,3].

# %%
numberList = [5,4,2,1,3]

# %% [markdown]
# Step. 2 Print the following values below:

# %%
len(numberList)
# Out:
# 5

# %%
numberList[0]
# Out:
# 5

# %%
numberList[1]
# Out:
# 4

# %%
numberList[2]
# Out:
# 2

# %%
numberList[3]
# Out:
# 1

# %%
numberList[4]
# Out:
# 3

# %%
numberList[4]
# Out:
# 3

# %%
numberList[-1]
# Out:
# 3

# %%
numberList[-2]
# Out:
# 1

# %%
numberList[-3]
# Out:
# 2

# %%
numberList[-4]
# Out:
# 4

# %%
numberList[-5]
# Out:
# 5

# %%
numberList[-6]

# %% [markdown]
# Step 3. Write your observation after printing all the values.

# %% [markdown]
# 4. Create a variable named itemlist and assign it the value of [1,-2.0,[1,2,3],”Word”]

# %%
itemlist = [1, -2.0, [1, 2, 3], "Word"]
print(itemlist)
# Out:
# [1, -2.0, [1, 2, 3], 'Word']

# %% [markdown]
# step 5. 5. Print the following values below:

# %%
len(itemlist)
# Out:
# 4

# %%
itemlist[0]
# Out:
# 1

# %%
itemlist[1]
# Out:
# -2.0

# %%
itemlist[2]
# Out:
# [1, 2, 3]

# %%
itemlist[3]
# Out:
# 'Word'

# %%
len(itemlist[2])
# Out:
# 3

# %%
itemlist [2][0]
# Out:
# 1

# %%
itemlist [2][1]
# Out:
# 2

# %%
itemlist [2][2]
# Out:
# 3

# %%
itemlist [-1]
# Out:
# 'Word'

# %%
itemlist [-2]
# Out:
# [1, 2, 3]

# %%
itemlist [-3]
# Out:
# -2.0

# %%
itemlist [-4]
# Out:
# 1
