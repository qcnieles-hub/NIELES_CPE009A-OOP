# %% [markdown]
# <a href="https://colab.research.google.com/github/qcnieles-hub/NIELES_CPE009A-OOP/blob/main/OOPConceptsNieles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

class Shapes:
    def __init__(self, name, sides):
        self.name = name
        self.sides = sides

    def description(self):
        return f"The {self.name} has {self.sides} sides."

    # Separate functions for each shape
    def triangle_area(self, d):
        return 0.5 * d.get('base', 0) * d.get('height', 0)

    def circle_area(self, d):
        return math.pi * (d.get('radius', 0) ** 2)

    def square_area(self, d):
        return d.get('side', 0) ** 2

    def rectangle_area(self, d):
        return d.get('length', 0) * d.get('width', 0)

    def calculate_area(self, **dimensions):
        formulas = {
            "triangle": self.triangle_area,
            "circle": self.circle_area,
            "square": self.square_area,
            "rectangle": self.rectangle_area
        }

        func = formulas.get(self.name.lower())
        if func:
            return func(dimensions)
        return 0


obj1 = Shapes("Triangle", 3)
obj2 = Shapes("Circle", 1)
obj3 = Shapes("Square", 4)
obj4 = Shapes("Rectangle", 4)

print(obj1.description())
print(f"Area of {obj1.name}: {obj1.calculate_area(base=10, height=8)}")

print(obj2.description())
area_c = obj2.calculate_area(radius=5)
print(f"Area of {obj2.name}: {area_c:.2f}")

print(obj3.description())
print(f"Area of {obj3.name}: {obj3.calculate_area(side=10)}")

print(obj4.description())
print(f"Area of {obj4.name}: {obj4.calculate_area(length=5, width=10)}")
# Out:
# The Triangle has 3 sides.
# Area of Triangle: 40.0
# The Circle has 1 sides.
# Area of Circle: 78.54
# The Square has 4 sides.
# Area of Square: 100
# The Rectangle has 4 sides.
# Area of Rectangle: 50

# %%
import math

class Shapes:
    def __init__(self, name, sides):
        self.name = name
        self.sides = sides

    def description(self):
        return f"The {self.name} has {self.sides} sides."

    # Separate functions for each shape
    def triangle_area(self, d):
        return 0.5 * d.get('base', 0) * d.get('height', 0)

    def circle_area(self, d):
        return math.pi * (d.get('radius', 0) ** 2)

    def square_area(self, d):
        return d.get('side', 0) ** 2

    def rectangle_area(self, d):
        return d.get('length', 0) * d.get('width', 0)

    def calculate_area(self, **dimensions):
        formulas = {
            "triangle": self.triangle_area,
            "circle": self.circle_area,
            "square": self.square_area,
            "rectangle": self.rectangle_area
        }

        func = formulas.get(self.name.lower())
        if func:
            return func(dimensions)
        return 0


obj1 = Shapes("Triangle", 3)
obj2 = Shapes("Circle", 1)
obj3 = Shapes("Square", 4)
obj4 = Shapes("Rectangle", 4)

print(obj1.description())
print(f"Area of {obj1.name}: {obj1.calculate_area(base=10, height=8)}")

print(obj2.description())
area_c = obj2.calculate_area(radius=5)
print(f"Area of {obj2.name}: {area_c:.2f}")

print(obj3.description())
print(f"Area of {obj3.name}: {obj3.calculate_area(side=10)}")

print(obj4.description())
print(f"Area of {obj4.name}: {obj4.calculate_area(length=5, width=10)}")
# Out:
# The Triangle has 3 sides.
# Area of Triangle: 40.0
# The Circle has 1 sides.
# Area of Circle: 78.54
# The Square has 4 sides.
# Area of Square: 100
# The Rectangle has 4 sides.
# Area of Rectangle: 50
