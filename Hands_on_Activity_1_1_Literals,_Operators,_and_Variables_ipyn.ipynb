# %% [markdown]
# <a href="https://colab.research.google.com/github/qcnieles-hub/NIELES_CPE009A-OOP/blob/main/Hands_on_Activity_1_1_Literals%2C_Operators%2C_and_Variables_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Laboratory Activity No.1** (Literals, Operators, and Variables)

# %% [markdown]
# **Name:** Cenndy M. Nieles
#
# **Section:** CPE12S2
#
# **Date Performed:** January 08, 2026

# %% [markdown]
# Assigning variables of different data types of Phython

# %% [markdown]
# 1.) In an empty cell, declare a variable value and assigned it  and assign it the value of 5 then display its value using print().

# %%
value = 5
print(value)
# Out:
# 5

# %% [markdown]
# 2.) Create a new cell and type the command: type(value) then run the cell. The output should be like the image  below.

# %%
type(value)
# Out:
# int

# %% [markdown]
# 3.) In a new cell, use the same variable value and assign it the value of 5.0 then print the value.

# %%
type(0.5)
# Out:
# float

# %% [markdown]
# 4.) Repeat step 2.
# Note: You may choose to decide how you execute the code in the cells for the next tasks in the procedure.

# %% [markdown]
# 5.) Repeat these steps for the following values:
#
# a. 2+3j
#
# b. ‘Hello World’
#
# c. “Hello World”
#
# d. True
#
# e. False
#
# f. [1,2,3,4,5]
#
# g. (1,2,3,4,5)
#
# h. { ‘name’: ‘Your_name’ }
#
# i. None

# %% [markdown]
# a. 2+3j

# %%
value = 2
value2 =3j
(value + value2)
# Out:
# (2+3j)

# %% [markdown]
# b. 'Hello World'

# %%
value = ("Hello")
value2 = ("World")
(value + " " + value2)
# Out:
# 'Hello World'

# %% [markdown]
# c. "Hello World"

# %%
value = "Hello"
value2 = "World"
(value + " " + value2)
# Out:
# 'Hello World'

# %% [markdown]
# d. True

# %%
value = True
print(value)
type(value)
# Out:
# True
# bool

# %% [markdown]
# e. False

# %%
value = False
print(value)
type(value)
# Out:
# False
# bool

# %% [markdown]
# f. [1,2,3,4,5]

# %%
value = [1, 2, 3, 4, 5]
print(value)
type(value)
# Out:
# [1, 2, 3, 4, 5]
# list

# %% [markdown]
# g. (1,2,3,4,5)

# %%
value = (1, 2, 3, 4, 5)
print(value)
type(value)
# Out:
# (1, 2, 3, 4, 5)
# tuple

# %% [markdown]
# h. { ‘name’: ‘Your_name’ }

# %%
value = {'name': 'Cenndy M. Nieles'}
print(value['name'])
# Out:
# Cenndy M. Nieles

# %% [markdown]
# i. None

# %%
x = None

if x is None:
    print("x is None")
# Out:
# x is None

# %% [markdown]
# 6.) Re-assign the value variable to be equal to 5.

# %%
value = 5
print(value)

# %% [markdown]
# 7. Declare a new variable named value2 to be equal to -6.

# %%
value = 5
value2= -6
print(value + value2)

# %% [markdown]
# Performing Operations with Python

# %%
value, value2 = -5.0, 6
print(value + value2)

# %% [markdown]
# 1. Using value and value2. Type the command: print(value+value2)

# %%
value, value2 = 5.0, 6
print(value + value2)

# %% [markdown]
# b. value, value2 = -5, 6.1

# %%
value, value2 = -5, 6.1
print(value + value2)

# %% [markdown]
# c. value, value2 = “Hello”, ‘world’

# %%
value, value2 = "Hello", "world"
print(value + " " + value2)

# %% [markdown]
# d. value, value2 = [1,2,3], [4,5,6]

# %%
value, value2 = [1, 2, 3], [4, 5, 6]
print(value + value2)

# %% [markdown]
# e. value, value2 = (1,2,3), (4,5,6)

# %%
value, value2 = (1, 2, 3), (4, 5, 6)
print(value + value2)

# %% [markdown]
# f. value, value2 = {"name":"Royce"}, {"age":2}

# %%
value, value2 = {"name": "Royce"}, {"age": 2}

print(value)   # {'name': 'Royce'}
print(value2)  # {'age': 2}

# %% [markdown]
# 3. Using value, value2 = 30, 4. Type the commands:

# %% [markdown]
# a. print(value*value2)

# %%
value = 30
value2 = 4

print(value * value2)

# %% [markdown]
#  b. print(value2**2)

# %%
value2 = 4
print(value2 ** 2)

# %% [markdown]
#  c. print(value2**3

# %%
value2 = 4
print(value2 ** 3)

# %% [markdown]
# d. print(value*value2+value2**2+1)

# %%
value2 = 4
print(value2 ** 2+1)

# %% [markdown]
# e. print(value/value2)

# %%
value = 30
value2 = 4

print(value / value2)

# %% [markdown]
# f. print(value%value2)

# %%
value = 30
value2 = 4
print(value % value2)

# %% [markdown]
# Assigning Input Data to a Variable

# %% [markdown]
# Finding a person’s BMI (metric)

# %% [markdown]
# 1. Declare a new variable named name and assign it the value input(“Enter your name”)

# %%
value = {'name': 'Cenndy M. Nieles'}
name = value['name']
print(name)
# Out:
# Cenndy M. Nieles

# %% [markdown]
# 2. Create another variable named weight and assign it the value input(“Enter your weight(kg): “)

# %%
value = {'weight': '50 kg'}
weight = value['weight']
print(weight)
# Out:
# 50 kg

# %% [markdown]
# 3. Create another variable named height and assign it the value input(“Enter your meters(m): “

# %%
value = {'height': '1.45 meters'}
height = value['height']
print(height)
# Out:
# 1.45 meters

# %% [markdown]
# 4.
# Declare another variable called bmi and assign it the formula 𝑏𝑚𝑖 = 𝑤𝑒𝑖𝑔ℎ𝑡
# ℎ𝑒𝑖𝑔ℎ𝑡2

# %%
weight = 50
height = 1.45

bmi = weight / (height ** 2)

print("Your BMI is:", round(bmi, 2))
# Out:
# Your BMI is: 23.78

# %% [markdown]
# 5. Address the errors displayed step#4. You can accomplish this by converting the String input to another data
# type. An example would be:
# weight = input(“Enter your weight(kg)”)
# weight = float(weight)
# Or simply weight = float(input(“Enter your weight(kg): “))
# There are many functions available that can convert one data type to another. Some of which are the following:
# int(), float(), str()
# Other functions which maybe used in the later lab activities are: complex(real, imaginary), list(), tuple(), set(),
# dict(), ord(), bin(), hex(),

# %%
print("Weight:", weight)
print("Height:", height)
print("BMI:", round(bmi, 4))
# Out:
# Weight: 50.0
# Height: 1.45
# BMI: 23.7812

# %% [markdown]
# 6. Print the persons’s name, weight, height, and bmi
# Name: John Ray
# Weight: 60
# Height: 1.6764
# BMI = 21.3499
# Guide: 5.5 feet ~ 1.6764 m

# %%
print("Name:", "John Ray")
print("Weight:", 60)
print("Height:", 1.6764)
print("BMI:", 21.3499)
# Out:
# Name: John Ray
# Weight: 60
# Height: 1.6764
# BMI: 21.3499

# %% [markdown]
# Receiving Input Data using Python

# %%
name = input("Cenndy M, Nieles: ")
print("Hello,", name)
# Out:
# Cenndy M, Nieles: hello
# Hello, hello

# %%
name = input("Cenndy:")
print(name)
# Out:
# Cenndy:cenndy
# cenndy

# %% [markdown]
# Tasks
# 1. Write the Python equivalent code of the following C code:

# %%
# Triangle Area Calculator in Python

# Ask the user for input
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))

# Compute the area
area = 0.5 * base * height

# Display the result
print("The area of the triangle is", area)
# Out:
# Enter the base of the triangle: 1
# Enter the height of the triangle: 3
# The area of the triangle is 1.5

# %% [markdown]
# 2. Write a program that would convert Celsius to Fahrenheit given the formula: F = (C × 9/5) + 32  Example of conversion:
# 0°C = 32 °F
# -20°C = -4 °F

# %%
# Celsius to Fahrenheit Converter

# Ask the user for Celsius input
celsius = float(input("Enter temperature in Celsius: "))

# Apply the conversion formula
fahrenheit = (celsius * 9/5) + 32

# Display the result
print(celsius, "°C =", fahrenheit, "°F")
# Out:
# Enter temperature in Celsius: 0
# 0.0 °C = 32.0 °F

# %% [markdown]
# 3. Write a program that can determine the distance between two points given the coordinates using the  formula:
# �� = √(���� − ����)�� + (���� − ����)��
# Hint/Rule: No library or package is needed to implement this equation.
# Example: x2, y2 = -3, 3 and x1, y1 = 2, 2 d = 5.099019514

# %%
# Distance between two points (no library needed)

# Input coordinates
x1 = float(input("Enter x1: "))
y1 = float(input("Enter y1: "))
x2 = float(input("Enter x2: "))
y2 = float(input("Enter y2: "))

# Apply the distance formula
distance = ((x2 - x1)**2 + (y2 - y1)**2) ** 0.5

# Display the result
print("The distance between the points is:", distance)
# Out:
# Enter x1: 2
# Enter y1: 2
# Enter x2: -3
# Enter y2: 3
# The distance between the points is: 5.0990195135927845
